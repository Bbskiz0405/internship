# %%
import requests
from bs4 import BeautifulSoup

# 設定PPT熱門看板的網址
url = "https://www.ptt.cc/bbs/hotboards.html"

# 發送HTTP GET請求
response = requests.get(url)

# 使用BeautifulSoup解析HTML
soup = BeautifulSoup(response.text, "html.parser")

# 爬取每個看板的名稱和網址
boards = soup.find_all('div', class_='board-name')
board_links = soup.find_all('a', class_='board')

# 取得看板名稱和網址
for board, link in zip(boards, board_links):
    board_name = board.text
    board_url = "https://www.ptt.cc" + link['href']
    print(f"看板名稱: {board_name}")
    print(f"網址: {board_url}\n")
# Out:
# 看板名稱: Gossiping
# 網址: https://www.ptt.cc/bbs/Gossiping/index.html
#
# 看板名稱: Baseball
# 網址: https://www.ptt.cc/bbs/Baseball/index.html
#
# 看板名稱: C_Chat
# 網址: https://www.ptt.cc/bbs/C_Chat/index.html
#
# 看板名稱: HatePolitics
# 網址: https://www.ptt.cc/bbs/HatePolitics/index.html
#
# 看板名稱: Stock
# 網址: https://www.ptt.cc/bbs/Stock/index.html
#
# 看板名稱: LoL
# 網址: https://www.ptt.cc/bbs/LoL/index.html
#
# 看板名稱: Lifeismoney
# 網址: https://www.ptt.cc/bbs/Lifeismoney/index.html
#
# 看板名稱: NBA
# 網址: https://www.ptt.cc/bbs/NBA/index.html
#
# 看板名稱: KoreaStar
# 網址: https://www.ptt.cc/bbs/KoreaStar/index.html
#
# 看板名稱: home-sale
# 網址: https://www.ptt.cc/bbs/home-sale/index.html
#
# 看板名稱: Elephants
# 網址: https://www.ptt.cc/bbs/Elephants/index.html
#
# 看板名稱: car
# 網址: https://www.ptt.cc/bbs/car/index.html
#
# 看板名稱: movie
# 網址: https://www.ptt.cc/bbs/movie/index.html
#
# 看板名稱: Lions
# 網址: https://www.ptt.cc/bbs/Lions/index.html
#
# 看板名稱: Tech_Job
# 網址: https://www.ptt.cc/bbs/Tech_Job/index.html
#
# 看板名稱: Japan_Travel
# 網址: https://www.ptt.cc/bbs/Japan_Travel/index.html
#
# 看板名稱: PC_Shopping
# 網址: https://www.ptt.cc/bbs/PC_Shopping/index.html
#
# 看板名稱: sex
# 網址: https://www.ptt.cc/bbs/sex/index.html
#
# 看板名稱: Beauty
# 網址: https://www.ptt.cc/bbs/Beauty/index.html
#
# 看板名稱: MobileComm
# 網址: https://www.ptt.cc/bbs/MobileComm/index.html
#
# 看板名稱: basketballTW
# 網址: https://www.ptt.cc/bbs/basketballTW/index.html
#
# 看板名稱: Steam
# 網址: https://www.ptt.cc/bbs/Steam/index.html
#
# 看板名稱: Marginalman
# 網址: https://www.ptt.cc/bbs/Marginalman/index.html
#
# 看板名稱: Monkeys
# 網址: https://www.ptt.cc/bbs/Monkeys/index.html
#
# 看板名稱: Guardians
# 網址: https://www.ptt.cc/bbs/Guardians/index.html
#
# 看板名稱: Tainan
# 網址: https://www.ptt.cc/bbs/Tainan/index.html
#
# 看板名稱: japanavgirls
# 網址: https://www.ptt.cc/bbs/japanavgirls/index.html
#
# 看板名稱: WomenTalk
# 網址: https://www.ptt.cc/bbs/WomenTalk/index.html
#
# 看板名稱: KoreaDrama
# 網址: https://www.ptt.cc/bbs/KoreaDrama/index.html
#
# 看板名稱: Badminton
# 網址: https://www.ptt.cc/bbs/Badminton/index.html
#
# 看板名稱: PlayStation
# 網址: https://www.ptt.cc/bbs/PlayStation/index.html
#
# 看板名稱: Military
# 網址: https://www.ptt.cc/bbs/Military/index.html
#
# 看板名稱: iOS
# 網址: https://www.ptt.cc/bbs/iOS/index.html
#
# 看板名稱: Kaohsiung
# 網址: https://www.ptt.cc/bbs/Kaohsiung/index.html
#
# 看板名稱: creditcard
# 網址: https://www.ptt.cc/bbs/creditcard/index.html
#
# 看板名稱: HardwareSale
# 網址: https://www.ptt.cc/bbs/HardwareSale/index.html
#
# 看板名稱: BabyMother
# 網址: https://www.ptt.cc/bbs/BabyMother/index.html
#
# 看板名稱: AllTogether
# 網址: https://www.ptt.cc/bbs/AllTogether/index.html
#
# 看板名稱: TaichungBun
# 網址: https://www.ptt.cc/bbs/TaichungBun/index.html
#
# 看板名稱: SportLottery
# 網址: https://www.ptt.cc/bbs/SportLottery/index.html
#
# 看板名稱: Boy-Girl
# 網址: https://www.ptt.cc/bbs/Boy-Girl/index.html
#
# 看板名稱: miHoYo
# 網址: https://www.ptt.cc/bbs/miHoYo/index.html
#
# 看板名稱: Japandrama
# 網址: https://www.ptt.cc/bbs/Japandrama/index.html
#
# 看板名稱: China-Drama
# 網址: https://www.ptt.cc/bbs/China-Drama/index.html
#
# 看板名稱: marriage
# 網址: https://www.ptt.cc/bbs/marriage/index.html
#
# 看板名稱: CFantasy
# 網址: https://www.ptt.cc/bbs/CFantasy/index.html
#
# 看板名稱: CVS
# 網址: https://www.ptt.cc/bbs/CVS/index.html
#
# 看板名稱: NSwitch
# 網址: https://www.ptt.cc/bbs/NSwitch/index.html
#
# 看板名稱: Gamesale
# 網址: https://www.ptt.cc/bbs/Gamesale/index.html
#
# 看板名稱: WOW
# 網址: https://www.ptt.cc/bbs/WOW/index.html
#
# 看板名稱: AC_In
# 網址: https://www.ptt.cc/bbs/AC_In/index.html
#
# 看板名稱: mobilesales
# 網址: https://www.ptt.cc/bbs/mobilesales/index.html
#
# 看板名稱: biker
# 網址: https://www.ptt.cc/bbs/biker/index.html
#
# 看板名稱: MacShop
# 網址: https://www.ptt.cc/bbs/MacShop/index.html
#
# 看板名稱: BeautySalon
# 網址: https://www.ptt.cc/bbs/BeautySalon/index.html
#
# 看板名稱: TW_Entertain
# 網址: https://www.ptt.cc/bbs/TW_Entertain/index.html
#
# 看板名稱: Drama-Ticket
# 網址: https://www.ptt.cc/bbs/Drama-Ticket/index.html
#
# 看板名稱: watch
# 網址: https://www.ptt.cc/bbs/watch/index.html
#
# 看板名稱: DIABLO
# 網址: https://www.ptt.cc/bbs/DIABLO/index.html
#
# 看板名稱: TWICE
# 網址: https://www.ptt.cc/bbs/TWICE/index.html
#
# 看板名稱: TY_Research
# 網址: https://www.ptt.cc/bbs/TY_Research/index.html
#
# 看板名稱: PokemonGO
# 網址: https://www.ptt.cc/bbs/PokemonGO/index.html
#
# 看板名稱: CarShop
# 網址: https://www.ptt.cc/bbs/CarShop/index.html
#
# 看板名稱: Hsinchu
# 網址: https://www.ptt.cc/bbs/Hsinchu/index.html
#
# 看板名稱: e-shopping
# 網址: https://www.ptt.cc/bbs/e-shopping/index.html
#
# 看板名稱: Aviation
# 網址: https://www.ptt.cc/bbs/Aviation/index.html
#
# 看板名稱: KR_Entertain
# 網址: https://www.ptt.cc/bbs/KR_Entertain/index.html
#
# 看板名稱: KoreanPop
# 網址: https://www.ptt.cc/bbs/KoreanPop/index.html
#
# 看板名稱: Bank_Service
# 網址: https://www.ptt.cc/bbs/Bank_Service/index.html
#
# 看板名稱: joke
# 網址: https://www.ptt.cc/bbs/joke/index.html
#
# 看板名稱: AzurLane
# 網址: https://www.ptt.cc/bbs/AzurLane/index.html
#
# 看板名稱: Headphone
# 網址: https://www.ptt.cc/bbs/Headphone/index.html
#
# 看板名稱: FORMULA1
# 網址: https://www.ptt.cc/bbs/FORMULA1/index.html
#
# 看板名稱: fastfood
# 網址: https://www.ptt.cc/bbs/fastfood/index.html
#
# 看板名稱: Tennis
# 網址: https://www.ptt.cc/bbs/Tennis/index.html
#
# 看板名稱: TaiwanDrama
# 網址: https://www.ptt.cc/bbs/TaiwanDrama/index.html
#
# 看板名稱: ONE_PIECE
# 網址: https://www.ptt.cc/bbs/ONE_PIECE/index.html
#
# 看板名稱: YuanChuang
# 網址: https://www.ptt.cc/bbs/YuanChuang/index.html
#
# 看板名稱: MLB
# 網址: https://www.ptt.cc/bbs/MLB/index.html
#
# 看板名稱: PublicServan
# 網址: https://www.ptt.cc/bbs/PublicServan/index.html
#
# 看板名稱: PuzzleDragon
# 網址: https://www.ptt.cc/bbs/PuzzleDragon/index.html
#
# 看板名稱: give
# 網址: https://www.ptt.cc/bbs/give/index.html
#
# 看板名稱: EAseries
# 網址: https://www.ptt.cc/bbs/EAseries/index.html
#
# 看板名稱: DC_SALE
# 網址: https://www.ptt.cc/bbs/DC_SALE/index.html
#
# 看板名稱: MakeUp
# 網址: https://www.ptt.cc/bbs/MakeUp/index.html
#
# 看板名稱: marvel
# 網址: https://www.ptt.cc/bbs/marvel/index.html
#
# 看板名稱: Salary
# 網址: https://www.ptt.cc/bbs/Salary/index.html
#
# 看板名稱: MuscleBeach
# 網址: https://www.ptt.cc/bbs/MuscleBeach/index.html
#
# 看板名稱: DigiCurrency
# 網址: https://www.ptt.cc/bbs/DigiCurrency/index.html
#
# 看板名稱: e-coupon
# 網址: https://www.ptt.cc/bbs/e-coupon/index.html
#
# 看板名稱: DSLR
# 網址: https://www.ptt.cc/bbs/DSLR/index.html
#
# 看板名稱: H-GAME
# 網址: https://www.ptt.cc/bbs/H-GAME/index.html
#
# 看板名稱: KanColle
# 網址: https://www.ptt.cc/bbs/KanColle/index.html
#
# 看板名稱: SuperBike
# 網址: https://www.ptt.cc/bbs/SuperBike/index.html
#
# 看板名稱: E-appliance
# 網址: https://www.ptt.cc/bbs/E-appliance/index.html
#
# 看板名稱: Moto_GP
# 網址: https://www.ptt.cc/bbs/Moto_GP/index.html
#
# 看板名稱: BabyProducts
# 網址: https://www.ptt.cc/bbs/BabyProducts/index.html
#
# 看板名稱: Audiophile
# 網址: https://www.ptt.cc/bbs/Audiophile/index.html
#
# 看板名稱: Key_Mou_Pad
# 網址: https://www.ptt.cc/bbs/Key_Mou_Pad/index.html
#
# 看板名稱: GBF
# 網址: https://www.ptt.cc/bbs/GBF/index.html
#
# 看板名稱: Road_Running
# 網址: https://www.ptt.cc/bbs/Road_Running/index.html
#
# 看板名稱: Railway
# 網址: https://www.ptt.cc/bbs/Railway/index.html
#
# 看板名稱: Wanted
# 網址: https://www.ptt.cc/bbs/Wanted/index.html
#
# 看板名稱: FAPL
# 網址: https://www.ptt.cc/bbs/FAPL/index.html
#
# 看板名稱: CheerGirlsTW
# 網址: https://www.ptt.cc/bbs/CheerGirlsTW/index.html
#
# 看板名稱: nb-shopping
# 網址: https://www.ptt.cc/bbs/nb-shopping/index.html
#
# 看板名稱: Teacher
# 網址: https://www.ptt.cc/bbs/Teacher/index.html
#
# 看板名稱: Food
# 網址: https://www.ptt.cc/bbs/Food/index.html
#
# 看板名稱: WCDragons
# 網址: https://www.ptt.cc/bbs/WCDragons/index.html
#
# 看板名稱: part-time
# 網址: https://www.ptt.cc/bbs/part-time/index.html
#
# 看板名稱: Vtuber
# 網址: https://www.ptt.cc/bbs/Vtuber/index.html
#
# 看板名稱: FATE_GO
# 網址: https://www.ptt.cc/bbs/FATE_GO/index.html
#
# 看板名稱: SakaTalk
# 網址: https://www.ptt.cc/bbs/SakaTalk/index.html
#
# 看板名稱: Soft_Job
# 網址: https://www.ptt.cc/bbs/Soft_Job/index.html
#
# 看板名稱: ToS
# 網址: https://www.ptt.cc/bbs/ToS/index.html
#
# 看板名稱: Taoyuan
# 網址: https://www.ptt.cc/bbs/Taoyuan/index.html
#
# 看板名稱: XBOX
# 網址: https://www.ptt.cc/bbs/XBOX/index.html
#
# 看板名稱: PathofExile
# 網址: https://www.ptt.cc/bbs/PathofExile/index.html
#
# 看板名稱: Examination
# 網址: https://www.ptt.cc/bbs/Examination/index.html
#
# 看板名稱: cookclub
# 網址: https://www.ptt.cc/bbs/cookclub/index.html
#
# 看板名稱: Hinatazaka46
# 網址: https://www.ptt.cc/bbs/Hinatazaka46/index.html
#
# 看板名稱: Digitalhome
# 網址: https://www.ptt.cc/bbs/Digitalhome/index.html
#
# 看板名稱: ALLPOST
# 網址: https://www.ptt.cc/bbs/ALLPOST/index.html
#
# 看板名稱: Foreign_Inv
# 網址: https://www.ptt.cc/bbs/Foreign_Inv/index.html
#
# 看板名稱: points
# 網址: https://www.ptt.cc/bbs/points/index.html
#
# 看板名稱: DMM_GAMES
# 網址: https://www.ptt.cc/bbs/DMM_GAMES/index.html
#
# 看板名稱: Hearthstone
# 網址: https://www.ptt.cc/bbs/Hearthstone/index.html
#
# 看板名稱: Chiayi
# 網址: https://www.ptt.cc/bbs/Chiayi/index.html

# %%
import re
import requests
from bs4 import BeautifulSoup
import os
import json
from datetime import datetime, timedelta

# PTT八卦板首頁網址
base_url = "https://www.ptt.cc/bbs/Gossiping/index.html"

# 設定 cookies 以繞過18禁限制
ptt_session = requests.Session()
ptt_session.cookies.set('over18', '1')

# 模擬瀏覽器的 headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# 爬取幾天內的文章（預設7天）
days_to_crawl = 7
start_date = datetime.now() - timedelta(days=days_to_crawl)

# 創建儲存文章的資料夾
if not os.path.exists('gossiping_posts'):
    os.mkdir('gossiping_posts')

def get_soup(url):
    try:
        response = ptt_session.get(url, headers=headers)
        if response.status_code != 200:
            print(f"HTTP 請求錯誤，狀態碼: {response.status_code}")
            return None
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    except Exception as e:
        print(f"抓取頁面時發生錯誤: {e}")
        return None

def sanitize_filename(filename):
    # 移除不合法的字元
    return re.sub(r'[<>:"/\\|?*]', '', filename)

def parse_post(link):
    if not link or not link['href']:
        print(f"無效的連結: {link}")
        return None
    
    post_url = "https://www.ptt.cc" + link['href']
    post_soup = get_soup(post_url)
    
    if not post_soup:
        print(f"無法取得文章頁面: {post_url}")
        return None
    
    # 取得文章資訊
    metadata = post_soup.find_all('span', class_='article-meta-value')
    
    if len(metadata) < 4:
        print(f"跳過無效文章: {post_url}")
        return None
    
    author = metadata[0].text
    title = metadata[2].text
    post_time_str = metadata[3].text
    post_time = datetime.strptime(post_time_str, '%a %b %d %H:%M:%S %Y')

    # 檢查文章是否在7天內
    if post_time < start_date:
        return None
    
    category = title.split(']')[0].strip('[') if ']' in title else '未分類'
    
    # 內文
    content = post_soup.find(id="main-content").text.split('※ 發信站')[0].strip()

    # 抓取留言
    comments = []
    comment_elements = post_soup.find_all('div', class_='push')
    for comment in comment_elements:
        push_userid = comment.find('span', class_='push-userid')
        push_content = comment.find('span', class_='push-content')
        push_time = comment.find('span', class_='push-ipdatetime')
        
        if push_userid and push_content and push_time:
            comments.append({
                'comment_author': push_userid.text.strip(),
                'comment_time': push_time.text.strip(),
                'comment_content': push_content.text.strip(': ').strip()
            })

    # 儲存每篇文章及其留言
    post_data = {
        'author': author,
        'title': title,
        'post_time': post_time_str,
        'content': content,
        'category': category,
        'comments': comments
    }
    
    # 以標題為檔名儲存，處理非法字元
    filename = f"{post_time.strftime('%Y%m%d_%H%M')}_{sanitize_filename(title[:30].strip())}.json"
    with open(os.path.join('gossiping_posts', filename), 'w', encoding='utf-8') as f:
        json.dump(post_data, f, ensure_ascii=False, indent=4)
    
    return post_data

def crawl_gossiping(base_url):
    url = base_url
    page = 0
    while True:
        print(f'正在爬取第 {page+1} 頁...')
        soup = get_soup(url)
        
        if not soup:
            print(f"無法取得頁面內容，停止爬取")
            break
        
        links = soup.find_all('div', class_='title')

        for link in links:
            if link.a:  # 檢查 link.a 是否存在
                #print(f"Current link: {link.a['href']}")
                parse_post(link.a)

        paging_div = soup.find('div', class_='btn-group-paging')
        if paging_div:
            paging_buttons = paging_div.find_all('a')
            if len(paging_buttons) < 2:
                print("無法找到下一頁，停止爬取")
                break
            
            prev_page_link = paging_buttons[1].get('href')
            if not prev_page_link:
                print("無法取得上一頁的連結，停止爬取")
                break
            url = "https://www.ptt.cc" + prev_page_link
            print(prev_page_link)
        else:
            print("無法找到 btn-group-paging 元素，停止爬取")
            break
        
        # 確保最後一篇文章存在且有連結
        if links and links[-1].a:
            last_post = parse_post(links[-1].a)
            if last_post and datetime.strptime(last_post['post_time'], '%a %b %d %H:%M:%S %Y') < start_date:
                print("已超過7天，停止爬取")
                break
        
        page += 1

# 開始爬取八卦版文章
crawl_gossiping(base_url)
# Out:
# 正在爬取第 1 頁...
# 跳過無效文章: https://www.ptt.cc/bbs/Gossiping/M.1725417932.A.55B.html
# /bbs/Gossiping/index38851.html
# 跳過無效文章: https://www.ptt.cc/bbs/Gossiping/M.1725417932.A.55B.html
# 正在爬取第 2 頁...
# /bbs/Gossiping/index38850.html
# 正在爬取第 3 頁...
# /bbs/Gossiping/index38849.html
# 正在爬取第 4 頁...
# /bbs/Gossiping/index38848.html
# 正在爬取第 5 頁...
# /bbs/Gossiping/index38847.html
# 正在爬取第 6 頁...
# /bbs/Gossiping/index38846.html
# 正在爬取第 7 頁...
# /bbs/Gossiping/index38845.html
# 正在爬取第 8 頁...
# /bbs/Gossiping/index38844.html
# 正在爬取第 9 頁...
# /bbs/Gossiping/index38843.html
# 正在爬取第 10 頁...
# /bbs/Gossiping/index38842.html
# 正在爬取第 11 頁...
# /bbs/Gossiping/index38841.html
# 正在爬取第 12 頁...
# /bbs/Gossiping/index38840.html
# 正在爬取第 13 頁...
# /bbs/Gossiping/index38839.html
# 正在爬取第 14 頁...
# /bbs/Gossiping/index38838.html
# 正在爬取第 15 頁...
# /bbs/Gossiping/index38837.html
# 正在爬取第 16 頁...
# /bbs/Gossiping/index38836.html
# 正在爬取第 17 頁...
# /bbs/Gossiping/index38835.html
# 正在爬取第 18 頁...
# /bbs/Gossiping/index38834.html
# 正在爬取第 19 頁...
# /bbs/Gossiping/index38833.html
# 正在爬取第 20 頁...
# /bbs/Gossiping/index38832.html
# 正在爬取第 21 頁...
# /bbs/Gossiping/index38831.html
# 正在爬取第 22 頁...
# /bbs/Gossiping/index38830.html
# 正在爬取第 23 頁...
# /bbs/Gossiping/index38829.html
# 正在爬取第 24 頁...
# /bbs/Gossiping/index38828.html
# 正在爬取第 25 頁...
# /bbs/Gossiping/index38827.html
# 正在爬取第 26 頁...
# /bbs/Gossiping/index38826.html
# 正在爬取第 27 頁...
# /bbs/Gossiping/index38825.html
# 正在爬取第 28 頁...
# /bbs/Gossiping/index38824.html
# 正在爬取第 29 頁...
# /bbs/Gossiping/index38823.html
# 正在爬取第 30 頁...
# /bbs/Gossiping/index38822.html
# 正在爬取第 31 頁...
# /bbs/Gossiping/index38821.html
# 正在爬取第 32 頁...
# /bbs/Gossiping/index38820.html
# 正在爬取第 33 頁...
# /bbs/Gossiping/index38819.html
# 正在爬取第 34 頁...
# /bbs/Gossiping/index38818.html
# 正在爬取第 35 頁...
# /bbs/Gossiping/index38817.html
# 正在爬取第 36 頁...
# /bbs/Gossiping/index38816.html
# 正在爬取第 37 頁...
# /bbs/Gossiping/index38815.html
# 正在爬取第 38 頁...
# /bbs/Gossiping/index38814.html
# 正在爬取第 39 頁...
# /bbs/Gossiping/index38813.html
# 正在爬取第 40 頁...
# /bbs/Gossiping/index38812.html
# 正在爬取第 41 頁...
# 跳過無效文章: https://www.ptt.cc/bbs/Gossiping/M.1725708601.A.32C.html
# /bbs/Gossiping/index38811.html
# 正在爬取第 42 頁...
# /bbs/Gossiping/index38810.html
# 正在爬取第 43 頁...
# /bbs/Gossiping/index38809.html
# 正在爬取第 44 頁...
# /bbs/Gossiping/index38808.html
# 正在爬取第 45 頁...
# /bbs/Gossiping/index38807.html
# 正在爬取第 46 頁...
# /bbs/Gossiping/index38806.html
# 正在爬取第 47 頁...
# /bbs/Gossiping/index38805.html
# 正在爬取第 48 頁...
# /bbs/Gossiping/index38804.html
# 正在爬取第 49 頁...
# /bbs/Gossiping/index38803.html
# 正在爬取第 50 頁...
# /bbs/Gossiping/index38802.html
# 正在爬取第 51 頁...
# /bbs/Gossiping/index38801.html
# 正在爬取第 52 頁...
# 抓取頁面時發生錯誤: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725697804.A.D9C.html
# 抓取頁面時發生錯誤: ('Connection aborted.', ConnectionResetError(10054, '遠端主機已強制關閉一個現存的連線。', None, 10054, None))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725697902.A.B33.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725697971.A.E27.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141EBFB90>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725697971.A.E27.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698133.A.2D2.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141EBEFD0>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698133.A.2D2.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698172.A.466.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142242690>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698172.A.466.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698321.A.FFE.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142243590>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698321.A.FFE.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698400.A.2D1.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142241810>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698400.A.2D1.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698446.A.1CA.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142241E50>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698446.A.1CA.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698468.A.4A9.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141EBFA90>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698468.A.4A9.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698529.A.5FF.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141EBF890>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698529.A.5FF.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698540.A.EE2.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141EBE050>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698540.A.EE2.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698601.A.238.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142467D50>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698601.A.238.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698722.A.6A6.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000141422403D0>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698722.A.6A6.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698744.A.82E.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000141422420D0>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698744.A.82E.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698751.A.DC0.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142242990>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698751.A.DC0.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698757.A.C6C.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142D75950>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698757.A.C6C.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698936.A.6A6.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142D75F50>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698936.A.6A6.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698942.A.6F7.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142D77DD0>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698942.A.6F7.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698956.A.274.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014141F5EA90>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698956.A.274.html
# /bbs/Gossiping/index38800.html
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/M.1725698956.A.274.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142D764D0>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得文章頁面: https://www.ptt.cc/bbs/Gossiping/M.1725698956.A.274.html
# 正在爬取第 53 頁...
# 抓取頁面時發生錯誤: HTTPSConnectionPool(host='www.ptt.cc', port=443): Max retries exceeded with url: /bbs/Gossiping/index38800.html (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014142D75090>: Failed to resolve 'www.ptt.cc' ([Errno 11001] getaddrinfo failed)"))
# 無法取得頁面內容，停止爬取

# %%
import os
import re
import requests
from bs4 import BeautifulSoup

# 定義抓取每本書的詳細資料
def get_book_content(book_url):
    response = requests.get(book_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # 抓取標題、作者、時間、內文
    title = soup.find('h1').text if soup.find('h1') else "Unknown Title"
    author = soup.find('h2').text if soup.find('h2') else "Unknown Author"
    content_div = soup.find('div', {'class': 'chapter'})
    
    # 抓取出版時間
    time = "Unknown Time"
    time_tag = soup.find(string="Release Date:")
    if time_tag:
        time = time_tag.find_next().text
    
    # 抓取內文
    content = content_div.text if content_div else "No content available"
    
    return title, author, time, content

# 定義主爬取函數
def scrape_books(base_url, book_limit=200):
    response = requests.get(base_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # 找到書籍的所有鏈接
    book_links = soup.find_all('a', href=True)
    
    # 過濾出有效的電子書鏈接
    books = []
    for link in book_links:
        href = link['href']
        if href.startswith('/ebooks/'):
            books.append(f'https://www.gutenberg.org{href}')
        if len(books) >= book_limit:
            break

    # 逐本書爬取內容
    for book_url in books:
        title, author, time, content = get_book_content(book_url)
        
        # 清理標題中的非法字符
        safe_title = re.sub(r'[\\/*?:"<>|]', "", title)
        file_name = f"{safe_title}.txt"
        
        # 存為本地檔案
        with open(file_name, 'w', encoding='utf-8') as f:
            f.write(f"Title: {title}\n")
            f.write(f"Author: {author}\n")
            f.write(f"Release Date: {time}\n")
            f.write("\n" + content)
        print(f"Saved: {file_name}")

# 執行爬取
scrape_books('https://www.gutenberg.org/browse/languages/zh')
# Out:
# Saved: Search.txt
# Saved: Search.txt
# Saved: Category Bookshelf.txt
# Saved: Offline Catalogs and Feeds.txt
# Saved: 豆棚閒話 by Ainajushi.txt
# Saved: 戲中戲 by Aiyuezhuren.txt
# Saved: 比目魚 by Aiyuezhuren.txt
# Saved: 比目魚 by Aiyuezhuren.txt
# Saved: Study of Inner Cultivation by Anonymous.txt
# Saved: 三字經 by Anonymous.txt
# Saved: 山水情 by Anonymous.txt
# Saved: 山海經 by Anonymous.txt
# Saved: 施公案 by Anonymous.txt
# Saved: 施公案 by Anonymous.txt
# Saved: 易經 by Anonymous.txt
# Saved: 木蘭奇女傳 by Anonymous.txt
# Saved: 海公案 by Anonymous.txt
# Saved: 燕丹子 by Anonymous.txt
# Saved: 狄公案 by Anonymous.txt
# Saved: 百家姓 by Anonymous.txt
# Saved: 禮記 by Anonymous.txt
# Saved: 綠牡丹 by Anonymous.txt
# Saved: 詩經 by Anonymous.txt
# Saved: 麟兒報 by Anonymous.txt
# Saved: Study of Inner Cultivation by Anonymous.txt
# Saved: Hu Die Mei by Nanyuedaoren.txt
# Saved: Qing Lou Meng by Tao Zor.txt
# Saved: 天豹圖 by Unknown.txt
# Saved: 梁公九諫 by Unknown.txt
# Saved: 長恨歌 by Juyi Bai.txt
# Saved: 李娃傳 by Xingjian Bai.txt
# Saved: 玉樓春 by Baiyundaoren.txt
# Saved: 漢書 by Gu Ban.txt
# Saved: 引鳳蕭 by Banyunyou.txt
# Saved: 今古奇觀 by Baowenglaoren.txt
# Saved: 後西游記 by Xuahua Biao.txt
# Saved: 飛跎全傳 by Zou Bixian.txt
# Saved: 佛說四十二章經 by Buddha.txt
# Saved: 紅樓夢 by Xueqin Cao.txt
# Saved: 洛神賦 by Zhi Cao.txt
# Saved: 晁氏儒言 一卷 by Yuezhi Chao.txt
# Saved: 水滸後傳 by Chen Chen.txt
# Saved: 幼學瓊林 by Yunsheng Cheng.txt
# Saved: 治世餘聞 by Hongmo Chen.txt
# Saved: 琵琶記 by Ming Gao.txt
# Saved: 雪月梅傳 by active 18th century Lang Chen.txt
# Saved: 龍川詞 by Liang Chen.txt
# Saved: 三國志 by Shou Chen.txt
# Saved: 隋唐演義 by active 1675-1695 Renhu Chu.txt
# Saved: 論語 by Confucius.txt
# Saved: 滬語開路 = Conversational Exercises in the Shanghai Dialect by Crofoot and Rawlinson.txt
# Saved: 白圭志 by active 1836 Xiangchuan Cui.txt
# Saved: 孟子字義疏證 by Zhen Dai.txt
# Saved: 安樂集 by Daochuo.txt
# Saved: 鄧析子 by Xi Deng.txt
# Saved: 醉醒石 by active 17th century Donglugukuangsheng.txt
# Saved: 唐鍾馗平鬼傳 by Dongshanyunzhongdaoren.txt
# Saved: 春秋繁露 by active 2nd century B.C. Zhongshu Dong.txt
# Saved: 虬髯客傳 by Guangting Du.txt
# Saved: 吳船錄 by Chengda Fan.txt
# Saved: 星槎勝覽 by Xin Fei.txt
# Saved: 星槎勝覽 by Xin Fei.txt
# Saved: 喻世明言 by Menglong Feng.txt
# Saved: 平妖傳 by Guanzhong Luo and Menglong Feng.txt
# Saved: 東周列國志 by Menglong Feng.txt
# Saved: 警世通言 by Menglong Feng.txt
# Saved: 醒世恆言 by Menglong Feng.txt
# Saved: 封氏聞見記 by jin shi 756 Yan Feng.txt
# Saved: Eight dwelling places of Buddhist immortals by Five colors stone.txt
# Saved: 白圭志 by active 1836 Xiangchuan Cui.txt
# Saved: 搜神記 by active 317-322 Bao Gan.txt
# Saved: 搜神記 volume 11-14 by active 317-322 Bao Gan.txt
# Saved: 搜神記 volume 1-3 by active 317-322 Bao Gan.txt
# Saved: 搜神記 volume 15-17 by active 317-322 Bao Gan.txt
# Saved: 搜神記 volume 18-20 by active 317-322 Bao Gan.txt
# Saved: 搜神記 volume 4-10 by active 317-322 Bao Gan.txt
# Saved: 琵琶記 by Ming Gao.txt
# Saved: 抱朴子 by Hong Ge.txt
# Saved: 西京雜記 by Hong Ge.txt
# Saved: 幽明錄 by Yiqing Liu.txt
# Saved: 明鏡公案 by Unknown.txt
# Saved: 公孫龍子 by active 3rd century B.C. Long Gongsun.txt
# Saved: 竇娥冤 by Hanqing Guan.txt
# Saved: 竇娥寃 by Hanqing Guan.txt
# Saved: 管子 by Zhong Guan.txt
# Saved: 管子 — Volume 01  Chapters 1-5 by Zhong Guan.txt
# Saved: 管子 — Volume 02  Chapters 6-10 by Zhong Guan.txt
# Saved: 鬼谷子 by active 4th century B.C. Guiguzi.txt
# Saved: 鬼谷子 by active 4th century B.C. Guiguzi.txt
# Saved: 穆天子传 by Pu Guo.txt
# Saved: 漢武帝別國洞冥記 by active 1st century Xian Guo.txt
# Saved: 日知錄 by Yanwu Gu.txt
# Saved: 海上花列傳 by Bangqing Han.txt
# Saved: 韩非子 by Fei Han.txt
# Saved: 風月夢 by active 19th century Hanshangmengren.txt
# Saved: 韓詩外傳 by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Complete by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Vol. 1-2 by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Vol. 3-4 by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Vol. 5-6 by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Vol. 7-8 by active 150 B.C. Ying Han.txt
# Saved: 韓詩外傳, Vol. 9-10 by active 150 B.C. Ying Han.txt
# Saved: 唐诗三百首 by Hengtangtuishi.txt
# Saved: 長生殿 by Sheng Hong.txt
# Saved: 菜根譚 by active 1596 Zicheng Hong.txt
# Saved: 菜根譚前後集 by active 1596 Zicheng Hong.txt
# Saved: 天豹圖 by Unknown.txt
# Saved: 筠州黃檗山斷際禪師傳法心要 by Huangbo.txt
# Saved: 山水小牘 by active 873-910 Mei Huangfu.txt
# Saved: 高士傳 by Mi Huangfu.txt
# Saved: 金剛般若波羅蜜經 by Kumarajiva and Kunshan Huang.txt
# Saved: 天妃顯聖錄 by Yao Yu Lin and Qi You Huang.txt
# Saved: 三略 by active 3rd century B.C. Shigong Huang.txt
# Saved: 明夷待訪錄 by Zongxi Huang.txt
# Saved: 鹽鐵論 by active 1st century B.C. Kuan Huan.txt
# Saved: 一枕奇 by Huayangsanren.txt
# Saved: 六祖壇經 by Huineng.txt
# Saved: 臺灣外紀 by active 1692 Risheng Jiang.txt
# Saved: 賈誼新書 by Yi Jia.txt
# Saved: 金石緣 by Jingtianzhuren.txt
# Saved: 閱微草堂筆記 by Yun Ji.txt
# Saved: 醒夢駢言 by active 17th century Juqizi.txt
# Saved: 孔叢子 by Fu Kong.txt
# Saved: 小爾雅 by Fu Kong.txt
# Saved: 續世說 by Pingzhong Kong.txt
# Saved: 桃花扇 by Shangren Kong.txt
# Saved: 金剛般若波羅蜜經 by Kumarajiva and Kunshan Huang.txt
# Saved: 補紅樓夢 by active 18th century-19th century Langhuanshanqiao.txt
# Saved: Dao De Jing A Minimalist Translation by Laozi.txt
# Saved: 老子 by Laozi.txt
# Saved: 道德經 by Laozi.txt
# Saved: Dao De Jing A Minimalist Translation by Laozi.txt
# Saved: The Chinese Classics — Volume 1 Confucian Analects by James Legge.txt
# Saved: The Chinese Classics with a translation, critical and exegetical notes,….txt
# Saved: The Chinese Classics — Volume 1 Confucian Analects by James Legge.txt
# Saved: The Chinese Classics with a translation, critical and exegetical notes,….txt
# Saved: 臺灣通史 by Heng Lian.txt
# Saved: 李太白集 by Bai Li.txt
# Saved: 李太白集 by Bai Li.txt
# Saved: 官場現形記 by Boyuan Li.txt
# Saved: 官場現形記 by Boyuan Li.txt
# Saved: 官場現形記 by Boyuan Li.txt
# Saved: 文明小史 by Boyuan Li.txt
# Saved: 海公案 by Anonymous.txt
# Saved: 孫子算經 by approximately 5th century Sunzi.txt
# Saved: 列子 by active 4th century B.C. Liezi.txt
# Saved: 脾胃論 by Gao Li.txt
# Saved: 李賀詩選 by He Li.txt
# Saved: 文心雕龍 by Xie Liu.txt
# Saved: 二刻拍案惊奇 by Mengchu Ling.txt
# Saved: 二刻拍案驚奇 by Mengchu Ling.txt
# Saved: 初刻拍案驚奇 by Mengchu Ling.txt
# Saved: 殺子報 by Lingyanqiaozi.txt
# Saved: Dao De Jing A Minimalist Translation by Laozi.txt
# Saved: Study of Inner Cultivation by Anonymous.txt
# Saved: True HeartMind by Sengcan.txt
# Saved: Dao De Jing A Minimalist Translation by Laozi.txt
# Saved: Study of Inner Cultivation by Anonymous.txt
# Saved: True HeartMind by Sengcan.txt
# Saved: 天妃顯聖錄 by Yao Yu Lin and Qi You Huang.txt
# Saved: 西海紀遊草 by Zhen Lin.txt
# Saved: 西海紀遊草 by Zhen Lin.txt
# Saved: 漱玉詞 by Qingzhao Li.txt
# Saved: 鏡花緣 by Ruzhen Li.txt
# Saved: 鏡花緣 by Ruzhen Li.txt
# Saved: 李義山詩集 by Shangyin Li.txt
# Saved: 天豹圖 by Unknown.txt
# Saved: 梁公九諫 by Unknown.txt
# Saved: 淮南子 by An Liu.txt
# Saved: 天豹圖 by Unknown.txt
# Saved: 老殘遊記 by E Liu.txt
# Saved: 老殘遊記 by E Liu.txt
# Saved: 老殘遊記續集 by E Liu.txt
# Saved: Wu De Ji by Guang Wei Liu.txt
# Saved: 海島算經 by active 3rd century-4th century Hui Liu.txt
# Saved: 郁離子 by Ji Liu.txt
# Saved: 人物志 by active 3rd century Shao Liu.txt
# Saved: 隋唐嘉話 by active 742-755 Su Liu.txt
# Saved: 大唐新語 by active 806-820 Su Liu.txt
# Saved: 列仙傳 by Xiang Liu.txt
# Saved: 列女傳 by Xiang Liu.txt
# Saved: 新序 by Xiang Liu.txt
# Saved: 說苑 by Xiang Liu.txt
# Saved: 說苑, Volume 13-16 by Xiang Liu.txt
# Saved: 說苑, Volume 1-4 by Xiang Liu.txt
# Saved: 說苑, Volume 17-20 by Xiang Liu.txt
# Saved: 說苑, Volume 5-8 by Xiang Liu.txt
# Saved: 說苑, Volume 9-12 by Xiang Liu.txt
# Saved: 文心雕龍 by Xie Liu.txt
# Saved: 西京雜記 by Xin Liu.txt
# Saved: 舊唐書 by Xu Liu.txt
# Saved: 世說新語 by Yiqing Liu.txt
# Saved: 幽明錄 by Yiqing Liu.txt
# Saved: 樂章集 by jin shi 1034 Yong Liu.txt
# Saved: 斬鬼傳 by Zhang Liu.txt
# Saved: 斬鬼傳 by Zhang Liu.txt
# Saved: 夢中緣 by jin shi 1715 Xiuxing Li.txt
# Saved: 合錦回文傳 by Yu Li.txt
# Saved: 無聲戲 by Yu Li.txt
# Saved: 肉蒲團 by Yu Li.txt
